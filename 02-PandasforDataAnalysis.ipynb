# %% [markdown]
# # Pandas library and its functions in python

# %% [markdown]
# # 5us6e2w

# %%
#importing pandas once is mandatory in every project file
pip install pandas

# %%
import pandas as pd

# %%
# Import CSV file into a pandas DataFrame
#for those who have their Dataset in their D folder
df = pd.read_csv('D:/DataSets/emp.csv')
df
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno
# 0    7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 2    7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 3    7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30
# 5    7499   ALLEN   SALESMAN  7698.0  02/20/2001  1600   300.0      30
# 6    7844  TURNER   SALESMAN  7698.0  09/08/2001  1500     0.0      30
# 7    7900   JAMES      CLERK  7698.0  12/03/2001   950     NaN      30
# 8    7521    WARD   SALESMAN  7698.0  02/22/2001  1250   500.0      30
# 9    7902    FORD    ANALYST  7566.0  02/03/2001  3000     NaN      20
# 10   7369   SMITH      CLERK  7902.0  12/17/2000   800     NaN      20
# 11   7788   SCOTT    ANALYST  7566.0  04/19/2007  3000     NaN      20
# ...

# %%
#If you have your dataset in C folder run this code, 
#make sure you put your dataset in the respective folder
# Goto C-> Users-> (your pc folder)-> Create a folder named as C_Datasets-> paste the dataset in this folder
df = pd.read_csv(r'C:\Users\Kashif\C_Datasets\Car_sales.csv')

# %%
# Display the first few rows of the DataFrame
#print("First 5 rows of the DataFrame:")
print(df.head())
# Out:
#    empno   ename        job     mgr    hiredate   sal    comm  deptno
# 0   7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 1   7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 2   7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 3   7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 4   7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30

# %%
# Display basic information about the DataFrame
print("\nBasic information about the DataFrame:")
print(df.info())
# Out:
# Basic information about the DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   empno     14 non-null     int64
#  1   ename     14 non-null     object
#  2   job       14 non-null     object
#  3   mgr       13 non-null     float64
#  4   hiredate  14 non-null     object
#  5   sal       14 non-null     int64
#  6   comm      4 non-null      float64
#  7   deptno    14 non-null     int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 1.0+ KB
# None

# %%
# Display summary statistics of numerical columns
print("\nSummary statistics of numerical columns:")
print(df.describe())
# Out:
# Summary statistics of numerical columns:
#              empno          mgr          sal         comm     deptno
# count    14.000000    13.000000    14.000000     4.000000  14.000000
# mean   7726.571429  7739.307692  2073.214286   550.000000  22.142857
# std     178.294361   103.714660  1182.503224   602.771377   8.017837
# min    7369.000000  7566.000000   800.000000     0.000000  10.000000
# 25%    7588.000000  7698.000000  1250.000000   225.000000  20.000000
# 50%    7785.000000  7698.000000  1550.000000   400.000000  20.000000
# 75%    7868.000000  7839.000000  2943.750000   725.000000  30.000000
# max    7934.000000  7902.000000  5000.000000  1400.000000  30.000000

# %%
# Unique values in a column
print(df['column_name'].unique())

# %%
# Count of unique values
print(df['column_name'].value_counts())

# %%
# Mean of a column
print(df['column_name'].mean())

# Median of a column
print(df['column_name'].median())

# Standard deviation of a column
print(df['column_name'].std())

# %%
# Rename columns
df_renamed = df.rename(columns={'sal': 'salary'})
print(df_renamed)
# Out:
#     empno   ename        job     mgr    hiredate  salary    comm  deptno
# 0    7839    KING  PRESIDENT     NaN  11/17/2001    5000     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0  05/01/2001    2850     NaN      30
# 2    7782   CLARK    MANAGER  7839.0  06/09/2001    2450     NaN      10
# 3    7566   JONES    MANAGER  7839.0  04/02/2001    2975     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  09/28/2001    1250  1400.0      30
# 5    7499   ALLEN   SALESMAN  7698.0  02/20/2001    1600   300.0      30
# 6    7844  TURNER   SALESMAN  7698.0  09/08/2001    1500     0.0      30
# 7    7900   JAMES      CLERK  7698.0  12/03/2001     950     NaN      30
# 8    7521    WARD   SALESMAN  7698.0  02/22/2001    1250   500.0      30
# 9    7902    FORD    ANALYST  7566.0  02/03/2001    3000     NaN      20
# 10   7369   SMITH      CLERK  7902.0  12/17/2000     800     NaN      20
# 11   7788   SCOTT    ANALYST  7566.0  04/19/2007    3000     NaN      20
# ...

# %%
df_renamed
# Out:
#     empno   ename        job     mgr    hiredate  salary    comm  deptno
# 0    7839    KING  PRESIDENT     NaN  11/17/2001    5000     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0  05/01/2001    2850     NaN      30
# 2    7782   CLARK    MANAGER  7839.0  06/09/2001    2450     NaN      10
# 3    7566   JONES    MANAGER  7839.0  04/02/2001    2975     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  09/28/2001    1250  1400.0      30
# 5    7499   ALLEN   SALESMAN  7698.0  02/20/2001    1600   300.0      30
# 6    7844  TURNER   SALESMAN  7698.0  09/08/2001    1500     0.0      30
# 7    7900   JAMES      CLERK  7698.0  12/03/2001     950     NaN      30
# 8    7521    WARD   SALESMAN  7698.0  02/22/2001    1250   500.0      30
# 9    7902    FORD    ANALYST  7566.0  02/03/2001    3000     NaN      20
# 10   7369   SMITH      CLERK  7902.0  12/17/2000     800     NaN      20
# 11   7788   SCOTT    ANALYST  7566.0  04/19/2007    3000     NaN      20
# ...

# %%
# Check for missing values
print("\nMissing values check:")
print(df.isnull().sum())
# Out:
# Missing values check:
# empno        0
# ename        0
# job          0
# mgr          1
# hiredate     0
# sal          0
# comm        10
# deptno       0
# dtype: int64

# %%
# Selecting a single column
single_column = df['empno']
single_column
# Out:
# 0     7839
# 1     7698
# 2     7782
# 3     7566
# 4     7654
# 5     7499
# 6     7844
# 7     7900
# 8     7521
# 9     7902
# 10    7369
# 11    7788
# 12    7876
# 13    7934
# Name: empno, dtype: int64

# %%
# Selecting multiple columns
multiple_columns = df[['empno', 'comm']]
multiple_columns
# Out:
#     empno    comm
# 0    7839     NaN
# 1    7698     NaN
# 2    7782     NaN
# 3    7566     NaN
# 4    7654  1400.0
# 5    7499   300.0
# 6    7844     0.0
# 7    7900     NaN
# 8    7521   500.0
# 9    7902     NaN
# 10   7369     NaN
# 11   7788     NaN
# 12   7876     NaN
# 13   7934     NaN

# %%
# Filtering rows based on multiple conditions
filtered_df = df[(df['sal'] > 2500) | (df['job'] == 'MANAGER')]

filtered_df
# Out:
#     empno  ename        job     mgr    hiredate   sal  comm  deptno
# 0    7839   KING  PRESIDENT     NaN  11/17/2001  5000   NaN      10
# 1    7698  BLAKE    MANAGER  7839.0  05/01/2001  2850   NaN      30
# 2    7782  CLARK    MANAGER  7839.0  06/09/2001  2450   NaN      10
# 3    7566  JONES    MANAGER  7839.0  04/02/2001  2975   NaN      20
# 9    7902   FORD    ANALYST  7566.0  02/03/2001  3000   NaN      20
# 11   7788  SCOTT    ANALYST  7566.0  04/19/2007  3000   NaN      20

# %%
# Sorting values
sorted_df = df.sort_values(by='empno', ascending=False)
sorted_df
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno
# 13   7934  MILLER      CLERK  7782.0  01/23/2002  1300     NaN      10
# 9    7902    FORD    ANALYST  7566.0  02/03/2001  3000     NaN      20
# 7    7900   JAMES      CLERK  7698.0  12/03/2001   950     NaN      30
# 12   7876   ADAMS      CLERK  7788.0  05/23/2007  1100     NaN      20
# 6    7844  TURNER   SALESMAN  7698.0  09/08/2001  1500     0.0      30
# 0    7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 11   7788   SCOTT    ANALYST  7566.0  04/19/2007  3000     NaN      20
# 2    7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 4    7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30
# 3    7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 8    7521    WARD   SALESMAN  7698.0  02/22/2001  1250   500.0      30
# ...

# %%
# Adding a new column
df['Net_Pay'] = df['sal'] + df['comm']
df['new_column']

# Dropping columns
df.drop(columns=['column1', 'column2'], inplace=True)

# Saving DataFrame to a new CSV file
df.to_csv('D:/DataSets/new_file.csv', index=False)

# %%
# Adding a new column
df['Net_Pay'] = df['sal'] + 100
df['Net_Pay']
# Out:
# 0     5100
# 1     2950
# 2     2550
# 3     3075
# 4     1350
# 5     1700
# 6     1600
# 7     1050
# 8     1350
# 9     3100
# 10     900
# 11    3100
# 12    1200
# 13    1400
# Name: Net_Pay, dtype: int64

# %%
df
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno  \
# 0    7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 2    7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 3    7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30
# 5    7499   ALLEN   SALESMAN  7698.0  02/20/2001  1600   300.0      30
# 6    7844  TURNER   SALESMAN  7698.0  09/08/2001  1500     0.0      30
# 7    7900   JAMES      CLERK  7698.0  12/03/2001   950     NaN      30
# 8    7521    WARD   SALESMAN  7698.0  02/22/2001  1250   500.0      30
# 9    7902    FORD    ANALYST  7566.0  02/03/2001  3000     NaN      20
# 10   7369   SMITH      CLERK  7902.0  12/17/2000   800     NaN      20
# 11   7788   SCOTT    ANALYST  7566.0  04/19/2007  3000     NaN      20
# ...

# %%
# Handling missing values
# Replace missing values with mean of the column
df.fillna(df.mean(), inplace=True)
# Out:
# C:\Users\Kashif\AppData\Local\Temp/ipykernel_8944/4004128931.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean())
#     empno   ename        job          mgr    hiredate   sal    comm  deptno
# 0    7839    KING  PRESIDENT  7739.307692  11/17/2001  5000   550.0      10
# 1    7698   BLAKE    MANAGER  7839.000000  05/01/2001  2850   550.0      30
# 2    7782   CLARK    MANAGER  7839.000000  06/09/2001  2450   550.0      10
# 3    7566   JONES    MANAGER  7839.000000  04/02/2001  2975   550.0      20
# 4    7654  MARTIN   SALESMAN  7698.000000  09/28/2001  1250  1400.0      30
# 5    7499   ALLEN   SALESMAN  7698.000000  02/20/2001  1600   300.0      30
# 6    7844  TURNER   SALESMAN  7698.000000  09/08/2001  1500     0.0      30
# ...

# %%
# Dropping columns
df.drop(columns=['comm'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   empno     14 non-null     int64
#  1   ename     14 non-null     object
#  2   job       14 non-null     object
#  3   mgr       13 non-null     float64
#  4   hiredate  14 non-null     object
#  5   sal       14 non-null     int64
#  6   deptno    14 non-null     int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 912.0+ bytes

# %%
# Replace missing values with mean of the column
df.fillna(df.mean, inplace=True)

# %%
# Fill NaN values in a single column with its mean
df['mgr'] = df['mgr'].fillna(df['mgr'].mean())

# %%
df
# Out:
#     empno   ename        job          mgr    hiredate   sal    comm  deptno  \
# 0    7839    KING  PRESIDENT  7739.307692  11/17/2001  5000   550.0      10
# 1    7698   BLAKE    MANAGER  7839.000000  05/01/2001  2850   550.0      30
# 2    7782   CLARK    MANAGER  7839.000000  06/09/2001  2450   550.0      10
# 3    7566   JONES    MANAGER  7839.000000  04/02/2001  2975   550.0      20
# 4    7654  MARTIN   SALESMAN  7698.000000  09/28/2001  1250  1400.0      30
# 5    7499   ALLEN   SALESMAN  7698.000000  02/20/2001  1600   300.0      30
# 6    7844  TURNER   SALESMAN  7698.000000  09/08/2001  1500     0.0      30
# 7    7900   JAMES      CLERK  7698.000000  12/03/2001   950   550.0      30
# 8    7521    WARD   SALESMAN  7698.000000  02/22/2001  1250   500.0      30
# 9    7902    FORD    ANALYST  7566.000000  02/03/2001  3000   550.0      20
# 10   7369   SMITH      CLERK  7902.000000  12/17/2000   800   550.0      20
# ...

# %%
# Drop rows with any missing values
# df.dropna(inplace=True)
# Drop specific columns

#columns_to_drop = ['comm']
#df.drop(columns=columns_to_drop, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   empno     14 non-null     int64
#  1   ename     14 non-null     object
#  2   job       14 non-null     object
#  3   mgr       14 non-null     float64
#  4   hiredate  14 non-null     object
#  5   sal       14 non-null     int64
#  6   deptno    14 non-null     int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 912.0+ bytes

# %%
# Display basic information about the DataFrame after cleaning
print("\nBasic information about the DataFrame after cleaning:")
print(df.info())

# Save cleaned DataFrame to a new CSV file

# %%
# exporting file for D folder students
df.to_csv('D:/DataSets/emp1.csv', index=False)

# %%
# exporting file for C folder students
df.to_csv(r'C:\Users\Kashif\C_Datasets\emp1.csv')

# %%
# Plot line chart
df.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
# Plot scatter plot
df.plot.scatter(x='sal', y='mgr')
# Out:
# <AxesSubplot:xlabel='sal', ylabel='mgr'>

# %%
# Plot vertical bar chart
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh()
# Out:
# <AxesSubplot:>

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.box()

# Plot area chart
df.plot.area()

# Plot pie chart
df.plot.pie(y='A')

# %%
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
# Plot area chart
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   empno     14 non-null     int64
#  1   ename     14 non-null     object
#  2   job       14 non-null     object
#  3   mgr       14 non-null     float64
#  4   hiredate  14 non-null     object
#  5   sal       14 non-null     int64
#  6   deptno    14 non-null     int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 912.0+ bytes
